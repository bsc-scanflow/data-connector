# %% [markdown]
# # CloudEdge DataScience Team (Training)

# %%
import sys
import os
sys.path.insert(0,'../..')

import scanflow
from scanflow.client import ScanflowClient
from scanflow.client import ScanflowTrackerClient
from scanflow.client import ScanflowDeployerClient

# %%
from scanflow.tools import env
print(env.get_env("SCANFLOW_SERVER_URI"))
print(env.get_env("SCANFLOW_TRACKER_URI"))
#print(env.get_env("SCANFLOW_TRACKER_LOCAL_URI"))
print(env.get_env("MLFLOW_S3_ENDPOINT_URL"))
print(env.get_env("AWS_ACCESS_KEY_ID"))
print(env.get_env("AWS_SECRET_ACCESS_KEY"))
# Out:
# http://84.88.189.179:32767
# http://84.88.189.179:32766
# http://84.88.189.179:32645
# scanflow
# scanflow123

# %%
# App folder
scanflow_path = "/home/rocky/k8s_resources/data-connector"
app_dir = os.path.join(scanflow_path, "examples/cloudedge/datascience")
app_name = "cloudedge"
team_name = "datascience"

# scanflow client
client = ScanflowClient(
             #if you defined "SCANFLOW_SERVER_URI", you dont need to provide this
             #scanflow_server_uri="http://172.30.0.50:46666",
             verbose=True)

# %%
# DUMY: now the modelling simply save a resnet model

executor1 = client.ScanflowExecutor(name='modeling', 
                      mainfile='modeling.py',
                      parameters={'model_name': 'mlperf-resnet',
                                  'model_path': '/workflow/model/0'},
                      requirements='requirements.txt')


##workflow1 
workflow1 = client.ScanflowWorkflow(name='resnet-wf', 
                     nodes=[executor1],
                     type = "batch",
                     output_dir = "/workflow")


app = client.ScanflowApplication(app_name = app_name,
                                 app_dir = app_dir,
                                 team_name = team_name,
                                 workflows=[workflow1])

# %%
dic = app.to_dict()
# Out:
# 10-Apr-24 10:41:41 -  INFO - workflow resnet-wf: {'name': 'resnet-wf', 'nodes': [{'name': 'modeling', 'node_type': 'executor', 'mainfile': 'modeling.py', 'parameters': {'model_name': 'mlperf-resnet', 'model_path': '/workflow/model/0'}, 'requirements': 'requirements.txt', 'dockerfile': None, 'base_image': None, 'env': None, 'image': None, 'timeout': None, 'resources': None, 'affinity': None}], 'edges': None, 'type': 'batch', 'resources': None, 'affinity': None, 'kedaSpec': None, 'hpaSpec': None, 'output_dir': '/workflow'}

# %%
build_app = client.build_ScanflowApplication(app = app, trackerPort=32765)
# Out:
# 10-Apr-24 10:41:42 -  INFO - Building image registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/modeling
# 10-Apr-24 10:41:42 -  INFO - [+] Image [registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/modeling] has been found in repository. registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/modeling:latest.

# %%
build_app.to_dict()
# Out:
# 10-Apr-24 10:41:42 -  INFO - workflow resnet-wf: {'name': 'resnet-wf', 'nodes': [{'name': 'modeling', 'node_type': 'executor', 'mainfile': 'modeling.py', 'parameters': {'model_name': 'mlperf-resnet', 'model_path': '/workflow/model/0'}, 'requirements': 'requirements.txt', 'dockerfile': None, 'base_image': None, 'env': None, 'image': 'registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/modeling:latest', 'timeout': None, 'resources': None, 'affinity': None}], 'edges': None, 'type': 'batch', 'resources': None, 'affinity': None, 'kedaSpec': None, 'hpaSpec': None, 'output_dir': '/workflow'}
# {'app_name': 'cloudedge',
#  'app_dir': '/home/rocky/k8s_resources/data-connector/examples/cloudedge/datascience',
#  'team_name': 'datascience',
#  'workflows': [{'name': 'resnet-wf',
#    'nodes': [{'name': 'modeling',
#      'node_type': 'executor',
#      'mainfile': 'modeling.py',
#      'parameters': {'model_name': 'mlperf-resnet',
#       'model_path': '/workflow/model/0'},
#      'requirements': 'requirements.txt',
#      'dockerfile': None,
#      'base_image': None,
#      'env': None,
#      'image': 'registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/modeling:latest',
#      'timeout': None,
#      'resources': None,
#      'affinity': None}],
#    'edges': None,
#    'type': 'batch',
#    'resources': None,
#    'affinity': None,
#    'kedaSpec': None,
#    'hpaSpec': None,
#    'output_dir': '/workflow'}],
#  'agents': None,
#  'tracker': {'image': 'registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/scanflow-tracker',
#   'nodePort': 32765}}

# %%
deployerClient = ScanflowDeployerClient(user_type="local",
                                        deployer="argo",
                                        k8s_config_file="/home/rocky/.kube/config")
# Out:
# 10-Apr-24 10:41:43 -  INFO - loading kubernetes configuration from /home/rocky/.kube/config
# 10-Apr-24 10:41:43 -  INFO - found local kubernetes configuration

# %%
await deployerClient.create_environment(app=build_app)
# Out:
# 10-Apr-24 10:40:02 -  INFO - [++]Creating env
# 10-Apr-24 10:40:02 -  INFO - [++]Creating namespace "scanflow-cloudedge-datascience"
# 10-Apr-24 10:40:02 -  INFO - create_namespace true
# 10-Apr-24 10:40:02 -  INFO - [++]Creating Role for 'default service account'
# 10-Apr-24 10:40:02 -  INFO - create_rolebinding info
# 10-Apr-24 10:40:02 -  INFO - [++]Creating s3 secret {'AWS_ACCESS_KEY_ID': 'scanflow', 'AWS_SECRET_ACCESS_KEY': 'scanflow123', 'MLFLOW_S3_ENDPOINT_URL': 'http://minio.scanflow-server.svc.cluster.local', 'AWS_ENDPOINT_URL': 'http://minio.scanflow-server.svc.cluster.local'}
# 10-Apr-24 10:40:02 -  INFO - create_secret true
# 10-Apr-24 10:40:02 -  INFO - [++]Creating tracker configmap {'TRACKER_STORAGE': 'postgresql://postgres:scanflow123@scanflow-postgres.scanflow-server.svc.cluster.local/scanflow-cloudedge-datascience', 'TRACKER_ARTIFACT': 's3://scanflow/scanflow-cloudedge-datascience'}
# 10-Apr-24 10:40:02 -  INFO - create_configmap true
# 10-Apr-24 10:40:02 -  INFO - [++]Creating client configmap {'SCANFLOW_TRACKER_URI': 'http://scanflow-tracker-service.scanflow-server.svc.cluster.local', 'SCANFLOW_SERVER_URI': 'http://scanflow-server-service.scanflow-server.svc.cluster.local', 'SCANFLOW_TRACKER_LOCAL_URI': 'http://scanflow-tracker.scanflow-cloudedge-datascience.svc.cluster.local'}
# 10-Apr-24 10:40:02 -  INFO - create_configmap true
# 10-Apr-24 10:40:02 -  INFO - [+] Starting local tracker: [scanflow-tracker].
# 10-Apr-24 10:40:02 -  INFO - create_deployment true
# 10-Apr-24 10:40:02 -  INFO - [+] Created tracker Deployment True
# 10-Apr-24 10:40:02 -  INFO - create_service true
# 10-Apr-24 10:40:02 -  INFO - [+] Created tracker Service True
# 10-Apr-24 10:40:02 -  INFO - create_pvc true
# True

# %%
await deployerClient.run_app(app=build_app)
# Out:
# 10-Apr-24 10:41:47 -  INFO - [++] Running workflow: [resnet-wf].
# 10-Apr-24 10:41:47 -  INFO - [+] output dir /workflow
# 10-Apr-24 10:41:47 -  INFO - [+] Create resnet-wf output PVC
# 10-Apr-24 10:41:47 -  INFO - create_pvc true
# 10-Apr-24 10:41:47 -  INFO - output dir created
# 10-Apr-24 10:41:47 -  INFO - env for executor {'AWS_ACCESS_KEY_ID': 'scanflow', 'AWS_SECRET_ACCESS_KEY': 'scanflow123', 'MLFLOW_S3_ENDPOINT_URL': 'http://minio.scanflow-server.svc.cluster.local', 'AWS_ENDPOINT_URL': 'http://minio.scanflow-server.svc.cluster.local', 'SCANFLOW_TRACKER_URI': 'http://scanflow-tracker-service.scanflow-server.svc.cluster.local', 'SCANFLOW_SERVER_URI': 'http://scanflow-server-service.scanflow-server.svc.cluster.local', 'SCANFLOW_TRACKER_LOCAL_URI': 'http://scanflow-tracker.scanflow-cloudedge-datascience.svc.cluster.local'}
# 10-Apr-24 10:41:47 -  INFO - [+] Building workflow: [resnet-wf:modeling].
# 10-Apr-24 10:41:47 -  INFO -  parameters: ['--model_name', 'mlperf-resnet', '--model_path', '/workflow/model/0']
# 10-Apr-24 10:41:47 -  INFO -  command: ['python', '/app/modeling/modeling.py']
# 10-Apr-24 10:41:47 -  INFO -  argo executor: None
# 10-Apr-24 10:41:47 -  INFO - [+] Building workflow: [resnet-wf- edges]
# 10-Apr-24 10:41:47 -  INFO - [+] Building workflow: [resnet-wf- dag]
# 10-Apr-24 10:41:47 -  INFO - Found local kubernetes config. Initialized with kube_config.
# 10-Apr-24 10:41:47 -  INFO - Checking workflow name/generatedName resnet-wf
# 10-Apr-24 10:41:47 -  INFO - Submitting workflow to Argo
# 10-Apr-24 10:41:47 -  INFO - Workflow resnet-wf has been submitted in "scanflow-cloudedge-datascience" namespace!
# 10-Apr-24 10:41:47 -  INFO - [+++] Workflow: [resnet-wf] has been submitted to argo {'apiVersion': 'argoproj.io/v1alpha1', 'kind': 'Workflow', 'metadata': {'creationTimestamp': '2024-04-10T08:41:47Z', 'generation': 1, 'managedFields': [{'apiVersion': 'argoproj.io/v1alpha1', 'fieldsType': 'FieldsV1', 'fieldsV1': {'f:spec': {}}, 'manager': 'OpenAPI-Generator', 'operation': 'Update', 'time': '2024-04-10T08:41:47Z'}], 'name': 'resnet-wf', 'namespace': 'scanflow-cloudedge-datascience', 'resourceVersion': '38601368', 'uid': '33ecf237-bf20-4bb0-bd74-985809e184f0'}, 'spec': {'affinity': {}, 'entrypoint': 'resnet-wf', 'templates': [{'dag': {'tasks': [{'name': 'modeling', 'template': 'modeling'}]}, 'name': 'resnet-wf'}, {'container': {'command': ['python', '/app/modeling/modeling.py', '--model_name', 'mlperf-resnet', '--model_path', '/workflow/model/0'], 'env': [{'name': 'AWS_ACCESS_KEY_ID', 'value': 'scanflow'}, {'name': 'AWS_SECRET_ACCESS_KEY', 'value': 'scanflow123'}, {'name': 'MLFLOW_S3_ENDPOINT_URL', 'value': 'http://minio.scanflow-server.svc.cluster.local'}, {'name': 'AWS_ENDPOINT_URL', 'value': 'http://minio.scanflow-server.svc.cluster.local'}, {'name': 'SCANFLOW_TRACKER_URI', 'value': 'http://scanflow-tracker-service.scanflow-server.svc.cluster.local'}, {'name': 'SCANFLOW_SERVER_URI', 'value': 'http://scanflow-server-service.scanflow-server.svc.cluster.local'}, {'name': 'SCANFLOW_TRACKER_LOCAL_URI', 'value': 'http://scanflow-tracker.scanflow-cloudedge-datascience.svc.cluster.local'}], 'image': 'registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/modeling:latest', 'imagePullPolicy': 'Always', 'volumeMounts': [{'mountPath': '/workflow', 'name': 'outputpath'}, {'mountPath': '/scanflow', 'name': 'scanflowpath'}]}, 'name': 'modeling'}], 'volumes': [{'name': 'outputpath', 'persistentVolumeClaim': {'claimName': 'resnet-wf'}}, {'name': 'scanflowpath', 'persistentVolumeClaim': {'claimName': 'scanflow-scanflow-cloudedge-datascience'}}]}}
# 10-Apr-24 10:41:47 -  INFO - [+] Workflow: [resnet-wf] was run successfully.
# apiVersion: argoproj.io/v1alpha1
#
# kind: Workflow
#
# metadata:
#   name: resnet-wf
#
# spec:
#
#   affinity: {}
#
#   entrypoint: resnet-wf
#
#   templates:
#     - dag:
#         tasks:
#           - name: modeling
#             template: modeling
#       name: resnet-wf
#     - container:
#         command:
#           - python
#           - /app/modeling/modeling.py
#           - --model_name
#           - mlperf-resnet
#           - --model_path
#           - /workflow/model/0
#         env:
#           - name: AWS_ACCESS_KEY_ID
#             value: scanflow
#           - name: AWS_SECRET_ACCESS_KEY
#             value: scanflow123
#           - name: MLFLOW_S3_ENDPOINT_URL
#             value: http://minio.scanflow-server.svc.cluster.local
#           - name: AWS_ENDPOINT_URL
#             value: http://minio.scanflow-server.svc.cluster.local
#           - name: SCANFLOW_TRACKER_URI
#             value: http://scanflow-tracker-service.scanflow-server.svc.cluster.local
#           - name: SCANFLOW_SERVER_URI
#             value: http://scanflow-server-service.scanflow-server.svc.cluster.local
#           - name: SCANFLOW_TRACKER_LOCAL_URI
#             value: http://scanflow-tracker.scanflow-cloudedge-datascience.svc.cluster.local
#         image: registry.gitlab.bsc.es/datacentric-computing/cloudskin-project/cloudskin-registry/modeling:latest
#         imagePullPolicy: Always
#         volumeMounts:
#           - mountPath: /workflow
#             name: outputpath
#           - mountPath: /scanflow
#             name: scanflowpath
#       name: modeling
#
#   volumes:
#     - name: outputpath
#       persistentVolumeClaim:
#         claimName: resnet-wf
#     - name: scanflowpath
#       persistentVolumeClaim:
#         claimName: scanflow-scanflow-cloudedge-datascience
# True

# %%
await deployerClient.delete_app(app=build_app)
# Out:
# 10-Apr-24 10:39:40 -  INFO - Found local kubernetes config. Initialized with kube_config.
# 10-Apr-24 10:39:40 -  INFO - cannot find workflows
# 10-Apr-24 10:39:40 -  ERROR - delete_pvc error
# 10-Apr-24 10:39:40 -  ERROR - delete_pv error
# False

# %%
trackerClient = ScanflowTrackerClient(
                        scanflow_tracker_local_uri="http://172.30.0.50:46670",
                        verbose=True)

# %%
trackerClient.save_app_model(app_name=app_name,
                            team_name=team_name,
                            model_name="mlperf-resnet")
# Out:
# 15-Jun-21 19:53:23 -  INFO - Found credentials in environment variables.
# 15-Jun-21 19:53:25 -  INFO - {}--{}
# INFO: 'mlperf' does not exist. Creating a new experiment
# 2021/06/15 19:53:28 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: mlperf-resnet, version 1

# %%
await deployerClient.clean_environment(app=build_app)
# Out:
# 10-Apr-24 10:39:48 -  INFO - [++] Stopping tracker: [scanflow-tracker].
# 10-Apr-24 10:39:48 -  INFO - delete_deployment true
# 10-Apr-24 10:39:48 -  INFO - delete_service true
# 10-Apr-24 10:39:48 -  INFO - [++]Delete tracker configmap scanflow-tracker-env
# 10-Apr-24 10:39:48 -  INFO - delete_configmap true
# 10-Apr-24 10:39:48 -  INFO - [++]Delete client configmap scanflow-client-env
# 10-Apr-24 10:39:48 -  INFO - delete_configmap true
# 10-Apr-24 10:39:48 -  INFO - [++]Delete s3 secret scanflow-secret
# 10-Apr-24 10:39:48 -  INFO - delete_secret true
# 10-Apr-24 10:39:48 -  INFO - [++]Delete rolebinding default-admin
# 10-Apr-24 10:39:48 -  INFO - delete_rolebinding info
# 10-Apr-24 10:39:48 -  INFO - [++]Delete namespace "scanflow-mlperf-datascience"
# 10-Apr-24 10:39:48 -  INFO - delete_namespace true
# 10-Apr-24 10:39:48 -  INFO - delete_pvc true
# True
